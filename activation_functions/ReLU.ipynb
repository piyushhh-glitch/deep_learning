# %% [markdown]
# ### ReLU Activation Functions - ReLU activation function outputs the input directly if it is positive; otherwise, it outputs zero

# %% [markdown]
# ### 1. Numpy Implementation

# %%
import numpy as np 

def relu(x):
    return np.maximum(0,x)

x=np.array([-3,-2,-1,0,1,2,3])

print(relu(x))
# Out:
# [0 0 0 0 1 2 3]

# %% [markdown]
# ### 2. Pytorch Implementation

# %%
import torch

x=torch.tensor([-3,-2,-1,0,1,2,3])

print(torch.relu(x))
# Out:
# tensor([0, 0, 0, 0, 1, 2, 3])

# %% [markdown]
# ### 3. Visualization

# %%
import matplotlib.pyplot as plt 

x=np.linspace(-10,10,200)

plt.figure(figsize=(6,4))
plt.plot(x,relu(x))

plt.title("ReLU Activation Function")
plt.xlabel("Input")
plt.ylabel("Output")

plt.grid(True)
plt.show()
