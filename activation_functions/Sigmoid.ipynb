# %% [markdown]
# ### Sigmoid Activation Function-Used For Binary Classification Models

# %% [markdown]
# ### 1. Numpy Implementation

# %%
import numpy as np
import matplotlib.pyplot as plt 

def sigmoid(x):
    return 1/(1+np.exp(-x))

x=np.array([-3,-2,-1,0,1,2,3])

print(sigmoid(x))
# Out:
# [0.04742587 0.11920292 0.26894142 0.5        0.73105858 0.88079708
#  0.95257413]

# %% [markdown]
# ### 2.Pytorch Implementation

# %%
import torch

x=torch.tensor([-3,-2,-1,0,1,2,3])

print(torch.sigmoid(x))
# Out:
# tensor([0.0474, 0.1192, 0.2689, 0.5000, 0.7311, 0.8808, 0.9526])

# %% [markdown]
# ### 3. Visualization

# %%
# Generate input values
x = np.linspace(-10, 10, 500)

# Compute Sigmoid output
y = sigmoid(x)

# Plot the Sigmoid curve
plt.figure(figsize=(8, 5))
plt.plot(x, y, color="blue", linewidth=2, label="Sigmoid")

plt.title("Sigmoid Activation Function")
plt.xlabel("Input")
plt.ylabel("Output")
plt.grid(True)
plt.legend()

plt.show()

# %% [markdown]
# ### It cuts the x -axis at exactly 0.5
