# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in C:\Users\HP\anaconda3\envs\deep_learning\Lib\site-packages (2.11.0+cu128)
# Requirement already satisfied: filelock in C:\Users\HP\anaconda3\envs\deep_learning\Lib\site-packages (from torch) (3.29.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in C:\Users\HP\anaconda3\envs\deep_learning\Lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools<82 in C:\Users\HP\anaconda3\envs\deep_learning\Lib\site-packages (from torch) (70.2.0)
# Requirement already satisfied: sympy>=1.13.3 in C:\Users\HP\anaconda3\envs\deep_learning\Lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in C:\Users\HP\anaconda3\envs\deep_learning\Lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in C:\Users\HP\anaconda3\envs\deep_learning\Lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in C:\Users\HP\anaconda3\envs\deep_learning\Lib\site-packages (from torch) (2026.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in C:\Users\HP\anaconda3\envs\deep_learning\Lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\Users\HP\anaconda3\envs\deep_learning\Lib\site-packages (from jinja2->torch) (3.0.3)

# %%
import torch 
import torch.nn as nn

# %%
#input
torch.manual_seed(42)
inputs=torch.tensor([1.0,2.0,3.0])

# %%
neuron=nn.Linear(in_features=3,out_features=1)

# %%
output=neuron(inputs)

# %%
output
# Out:
# tensor([1.5244], grad_fn=<ViewBackward0>)

# %%
#verify the formula
neuron.weight  @ inputs +neuron.bias
# Out:
# tensor([1.5244], grad_fn=<AddBackward0>)

# %%
neuron.bias
# Out:
# Parameter containing:
# tensor([0.5304], requires_grad=True)

# %%
neuron.weight
# Out:
# Parameter containing:
# tensor([[ 0.4414,  0.4792, -0.1353]], requires_grad=True)
