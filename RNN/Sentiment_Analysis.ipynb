# %% [markdown]
# ### RNN for Sentiment Analysis

# %%
import pandas as pd

# %%
df=pd.read_csv("IMDB Dataset.csv")

# %%
df.shape
# Out:
# (50000, 2)

# %%
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
df.isnull().sum()
# Out:
# review       0
# sentiment    0
# dtype: int64

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (49582, 2)

# %% [markdown]
# ### Text Preprocessing

# %% [markdown]
# ## 1. Converting to lower case

# %%
df["review"]=df["review"].str.lower()

# %% [markdown]
# ## 2. Removing the urls

# %%
import re

# %%
def remove_urls(text):
    text=re.sub(r"http\S+", "",text)  # pattern , replacement , string
    return text

# %%
df["review"]=df["review"].apply(remove_urls)

# %% [markdown]
# ### 3. Remove Punctuations

# %%
def remove_punctuations(text):
    text=re.sub(r"[^A-Za-z0-9\s]","",text)
    return text

# %%
df["review"]=df["review"].apply(remove_punctuations)

# %% [markdown]
# ### 4. Removing HTML

# %%
def remove_html(text):
    text=re.sub(r"<.*?>","",text)
    return text

# %%
df["review"]=df["review"].apply(remove_html)

# %% [markdown]
# ### 5. Removing the Stopwords

# %%
import nltk

# %%
nltk.download("punkt")
nltk.download("punkt_tab")
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\HP\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
sample_text="I love to code in Python!"
tokens=word_tokenize(sample_text)

# %%
tokens
# Out:
# ['I', 'love', 'to', 'code', 'in', 'Python', '!']

# %%
def remove_stopwords(text):
    tokens=word_tokenize(text)
    stop_words=stopwords.words("english")

    for word in tokens:
        if word in stop_words:
            text=text.replace(word, "")

    return text

# %%
df["review"]=df["review"].apply(remove_stopwords)

# %%
df.head()
# Out:
#                                               review sentiment
# 0  e    revewers  nted   wtchg  1 oz epode ll  ho...  positive
# 1   wderful ltle producti br br  filming techniqu...  positive
# 2   thought ths   wderful wy  spend tme   o hot s...  positive
# 3  bsclly res  fmly   lttle boy jke thks res  zom...  negative
# 4  petter mtte love   time  mey   vully stunng fi...  positive

# %% [markdown]
# ### 6. Stemming

# %%
# running=>run
# playing=>play

# %%
from nltk.stem import PorterStemmer

# %%
def stemming(text):
    ps=PorterStemmer()
    stemmed_words=[]

    tokens=word_tokenize(text)
    for token in tokens:
        stemmed_tokens=ps.stem(token)
        stemmed_words.append(stemmed_tokens)

    return " ".join(stemmed_words)

# %%
df["review"]=df["review"].apply(stemming)

# %%
df.head()
# Out:
#                                               review sentiment
# 0  e revew nted wtchg 1 oz epod ll hook y rght ex...  positive
# 1  wder ltle producti br br film techniqu unssum ...  positive
# 2  thought th wder wy spend tme o hot summer week...  positive
# 3  bsclli re fmli lttle boy jke thk re zomb close...  negative
# 4  petter mtte love time mey vulli stunng film wt...  positive

# %% [markdown]
# ### 7. Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df["sentiment"]=le.fit_transform(df["sentiment"])

# %%
y=df["sentiment"]

# %%
y
# Out:
# 0        1
# 1        1
# 2        1
# 3        0
# 4        1
#         ..
# 49995    1
# 49996    0
# 49997    0
# 49998    0
# 49999    0
# Name: sentiment, Length: 49582, dtype: int64

# %% [markdown]
# ### 8. Vectorization

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tf=TfidfVectorizer(max_features=5000)

X=tf.fit_transform(df["review"])

# %%
X
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 4057140 stored elements and shape (49582, 5000)>

# %%
print(X)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 4057140 stored elements and shape (49582, 5000)>
#   Coords	Values
#   (0, 3538)	0.05515484681268887
#   (0, 2868)	0.09361182809242374
#   (0, 4940)	0.11467310366614668
#   (0, 3002)	0.47200539890110405
#   (0, 1275)	0.1357698919196183
#   (0, 2289)	0.049500237517476293
#   (0, 1933)	0.0791260308382
#   (0, 3550)	0.0963974330192639
#   (0, 1362)	0.06162489377343992
#   (0, 1963)	0.061560444992697486
#   (0, 219)	0.08588920995304898
#   (0, 1620)	0.0738170550485134
#   (0, 4369)	0.041994187696759305
#   (0, 4171)	0.17799685402440263
#   (0, 3693)	0.033532198172897175
#   (0, 4737)	0.26798942924092045
#   (0, 3805)	0.04427609784380831
#   (0, 4769)	0.05877405881441711
#   (0, 1739)	0.037520883911174724
#   (0, 4497)	0.07614066339174266
#   (0, 3857)	0.17537900435282314
#   (0, 1630)	0.06142445471882175
#   (0, 1862)	0.07433134577032253
#   (0, 3329)	0.06406818508428483
#   (0, 3332)	0.0844754682576354
#   :	:
#   (49581, 4890)	0.10682334916138103
#   (49581, 1542)	0.17584072573791829
#   (49581, 4494)	0.09410069396961679
#   (49581, 434)	0.11251655954741112
#   (49581, 4277)	0.10905956327445408
#   (49581, 1958)	0.0999074542943991
#   (49581, 555)	0.08424218838425554
#   (49581, 2187)	0.14180348667063264
#   (49581, 2217)	0.09535602544797335
#   (49581, 4347)	0.17508214877875983
#   (49581, 4629)	0.1157123083349983
#   (49581, 3647)	0.087334023293812
#   (49581, 4734)	0.12354122837064464
#   (49581, 1977)	0.1279546327938257
#   (49581, 527)	0.1247934452922504
#   (49581, 2621)	0.17341357547872566
#   (49581, 4458)	0.16002233459530202
#   (49581, 2174)	0.18983797727912208
#   (49581, 4033)	0.20100044911463438
#   (49581, 341)	0.14784964476913964
#   (49581, 2695)	0.1740080872946952
#   (49581, 439)	0.13323526536564564
#   (49581, 4980)	0.15095820717373318
#   (49581, 1764)	0.15815315432712562
#   (49581, 3489)	0.1519741559925848
